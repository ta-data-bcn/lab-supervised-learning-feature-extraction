# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
#Import your libraries
import numpy as np
import pandas as pd

# %% [markdown]
# # Introduction
#
# In this lab, we will use two datasets. Both datasets contain variables that describe apps from the Google Play Store. We will use our knowledge in feature extraction to process these datasets and prepare them for the use of a ML algorithm.

# %% [markdown]
# # Challenge 1 - Loading and Extracting Features from the First Dataset

# %% [markdown]
# #### In this challenge, our goals are:
#
# * Exploring the dataset.
# * Identify the columns with missing values.
# * Either replacing the missing values in each column or drop the columns.
# * Conver each column to the appropriate type.

# %% [markdown]
# #### The first dataset contains different information describing the apps.
#
# Load the dataset into the variable `google_play` in the cell below. The dataset is in the file `googleplaystore.csv`

# %%
# Your code here:
google_play = pd.read_csv("../../data/googleplaystore.csv")

# %% [markdown]
# #### Examine all variables and their types in the following cell

# %%
# Your code here:
google_play.dtypes
google_play.shape # (10841, 13)
google_play.isna().sum()/len(google_play) * 100 # rating 13%, others have one NA
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %% [markdown]
# #### Since this dataset only contains one numeric column, let's skip the `describe()` function and look at the first 5 rows using the `head()` function

# %%
# Your code here:
google_play.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# #### We can see that there are a few columns that could be coerced to numeric.
#
# Start with the reviews column. We can evaluate what value is causing this column to be of object type finding the non-numeric values in this column. To do this, we recall the `to_numeric()` function. With this function, we are able to coerce all non-numeric data to null. We can then use the `isnull()` function to subset our dataframe using the True/False column that this function generates.
#
# In the cell below, transform the Reviews column to numeric and assign this new column to the variable `Reviews_numeric`. Make sure to coerce the errors.

# %%
google_play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Your code here:
google_play["Reviews_numeric"] = google_play["Reviews"].apply(pd.to_numeric, errors='coerce')
google_play.loc[10472]
# Out:
# App                Life Made WI-Fi Touchscreen Photo Frame
# Category                                               1.9
# Rating                                                  19
# Reviews                                               3.0M
# Size                                                1,000+
# Installs                                              Free
# Type                                                     0
# Price                                             Everyone
# Content Rating                                         NaN
# Genres                                   February 11, 2018
# Last Updated                                        1.0.19
# Current Ver                                     4.0 and up
# Android Ver                                            NaN
# Reviews_numeric                                        NaN
# Name: 10472, dtype: object

# %% [markdown]
# Next, create a column containing True/False values using the `isnull()` function. Assign this column to the `Reviews_isnull` variable.

# %%
# Your code here:
google_play["Reviews_isnull"] = google_play["Reviews_numeric"].isnull()
google_play.loc[10472]
# Out:
# App                Life Made WI-Fi Touchscreen Photo Frame
# Category                                               1.9
# Rating                                                  19
# Reviews                                               3.0M
# Size                                                1,000+
# Installs                                              Free
# Type                                                     0
# Price                                             Everyone
# Content Rating                                         NaN
# Genres                                   February 11, 2018
# Last Updated                                        1.0.19
# Current Ver                                     4.0 and up
# Android Ver                                            NaN
# Reviews_numeric                                        NaN
# Reviews_isnull                                        True
# Name: 10472, dtype: object

# %% [markdown]
# Finally, subset the `google_play` with `Reviews_isnull`. This should give you all the rows that contain non-numeric characters.
#
# Your output should look like:
#
# ![Reviews_bool.png](../images/reviews-bool.png)

# %%
# Your code here:
google_play[google_play["Reviews_isnull"]==True]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  Reviews_numeric  Reviews_isnull
# 10472       1.0.19  4.0 and up         NaN              NaN            True

# %% [markdown]
# #### We see that Google Play is using a shorthand for millions.
#
# Let's write a function to transform this data.
#
# Steps:
#
# 1. Create a function that returns the correct numeric values of *Reviews*.
# 1. Define a test string with `M` in the last character.
# 1. Test your function with the test string. Make sure your function works correctly. If not, modify your functions and test again.

# %%
# Your code here

def convert_string_to_numeric(s):
    if "M" in s:
        return float(s[:-1])*1000000
    else:
        return s
    

test_string = '4.0M'

convert_string_to_numeric(test_string) == 4000000.0
# Out:
# True

# %% [markdown]
# The last step is to apply the function to the `Reviews` column in the following cell:

# %%
# Your code here:
google_play["Reviews"] = google_play["Reviews"].apply(convert_string_to_numeric)

# %% [markdown]
# Check the non-numeric `Reviews` row again. It should have been fixed now and you should see:
#
# ![Reviews_bool_fixed.png](../images/reviews-bool-fixed.png)

# %%
# Your code here
google_play["Reviews_numeric"] = google_play["Reviews"].apply(pd.to_numeric, errors='coerce')
google_play["Reviews_isnull"] = google_play["Reviews_numeric"].isnull()
google_play[google_play["Reviews_isnull"]==True]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Reviews_numeric, Reviews_isnull]
# Index: []

# %% [markdown]
# Also check the variable types of `google_play`. The `Reviews` column should be a `float64` type now.

# %%
# Your code here:
google_play.Rating.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# #### The next column we will look at is `Size`. We start by looking at all unique values in `Size`:
#
# *Hint: use `unique()` ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html))*.

# %%
# Your code here:
google_play.Size.unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %% [markdown]
# You should have seen lots of unique values of the app sizes.
#
# #### While we can convert most of the `Size` values to numeric in the same way we converted the `Reviews` values, there is one value that is impossible to convert.
#
# What is that badass value? Enter it in the next cell and calculate the proportion of its occurence to the total number of records of `google_play`.

# %%
# Your code here:
google_play["Size"] = google_play["Size"].apply(convert_string_to_numeric)
google_play["Size_numeric"] = google_play["Size"].apply(pd.to_numeric, errors='coerce')
google_play["Size_isnull"] = google_play["Size_numeric"].isnull()
google_play[google_play["Size_isnull"]==True]

# Varies with device
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 58                                     Restart Navigator    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# 73                                                PDD-UA    AUTO_AND_VEHICLES
# 85     CarMax – Cars for Sale: Search Used Car Inventory    AUTO_AND_VEHICLES
# 88           AutoScout24 Switzerland – Find your new car    AUTO_AND_VEHICLES
# 89     Zona Azul Digital Fácil SP CET - OFFICIAL São ...    AUTO_AND_VEHICLES
# 92                               Fuelio: Gas log & costs    AUTO_AND_VEHICLES
# 102                           Mirror - Zoom & Exposure -               BEAUTY
# 107                                          Ulta Beauty               BEAUTY
# 109                                        Selfie Camera               BEAUTY
# 117                        Beauty Camera - Selfie Camera               BEAUTY
# 118                                     Girls Hairstyles               BEAUTY
# 139                                 Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# 142                                            Wikipedia  BOOKS_AND_REFERENCE
# 143                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 144                                          Cool Reader  BOOKS_AND_REFERENCE
# 145                         Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE
# 146                        NOOK: Read eBooks & Magazines  BOOKS_AND_REFERENCE
# 149                       FBReader: Favorite Book Reader  BOOKS_AND_REFERENCE
# 152                                    Google Play Books  BOOKS_AND_REFERENCE
# 157                           Spanish English Translator  BOOKS_AND_REFERENCE
# 162                            NOOK App for NOOK Devices  BOOKS_AND_REFERENCE
# 172                                             Ancestry  BOOKS_AND_REFERENCE
# 173                                             HTC Help  BOOKS_AND_REFERENCE
# 179                                         Moon+ Reader  BOOKS_AND_REFERENCE
# 187                         Visual Voicemail by MetroPCS             BUSINESS
# ...                                                  ...                  ...
# 10595                        Florida Driver License Test               FAMILY
# 10600                        Restaurant Inspections - FL   HEALTH_AND_FITNESS
# 10642                                         WICShopper             SHOPPING
# 10645                       Football Manager Mobile 2018               SPORTS
# 10647                                  Motorola FM Radio        VIDEO_PLAYERS
# 10667                                  Bullet - FN Theme      PERSONALIZATION
# 10675                        Circle Colors Pack-FN Theme      PERSONALIZATION
# 10677                                    Pint - FN Theme      PERSONALIZATION
# 10678                                HAL-9000 - FN Theme      PERSONALIZATION
# 10679                                         Solitaire+                 GAME
# 10681                                       Future Cloud         PRODUCTIVITY
# 10688                                    Fo File Manager                TOOLS
# 10690                                           FO Bixby      PERSONALIZATION
# 10707                     Photo Editor Collage Maker Pro          PHOTOGRAPHY
# 10712                              Lalafo Pulsuz Elanlar             SHOPPING
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10732                                 Draw with FP sDraw                TOOLS
# 10735                                        FP VoiceBot               FAMILY
# 10751                                          FP Market               FAMILY
# 10755                                     Hondata Mobile  MAPS_AND_NAVIGATION
# 10759                                     FP NFC Rewrite                TOOLS
# 10763                                FP Разбитый дисплей               FAMILY
# 10764                                  FP Transportation    AUTO_AND_VEHICLES
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10798                               Word Search Tab 1 FR               FAMILY
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating  Reviews                Size        Installs  Type  Price  \
# 37        4.1    36639  Varies with device      5,000,000+  Free      0
# 42        4.4   295221  Varies with device     10,000,000+  Free      0
# 52        4.6    17057  Varies with device      1,000,000+  Free      0
# 58        4.0     1403                201k        100,000+  Free      0
# 67        4.3    40211  Varies with device      5,000,000+  Free      0
# 68        3.9      356  Varies with device        100,000+  Free      0
# 73        4.8      736  Varies with device        100,000+  Free      0
# 85        4.4    21777  Varies with device      1,000,000+  Free      0
# 88        4.6    13372  Varies with device      1,000,000+  Free      0
# 89        4.6     7880  Varies with device        100,000+  Free      0
# 92        4.6    65786  Varies with device      1,000,000+  Free      0
# 102       3.9    32090  Varies with device      1,000,000+  Free      0
# 107       4.7    42050  Varies with device      1,000,000+  Free      0
# 109       4.2    17934  Varies with device      1,000,000+  Free      0
# 117       4.0   113715  Varies with device     10,000,000+  Free      0
# 118       4.1     3595  Varies with device        500,000+  Free      0
# 139       4.6  2914724  Varies with device    100,000,000+  Free      0
# 142       4.4   577550  Varies with device     10,000,000+  Free      0
# 143       4.2   814080  Varies with device    100,000,000+  Free      0
# 144       4.5   246315  Varies with device     10,000,000+  Free      0
# 145       4.5   454060  Varies with device     10,000,000+  Free      0
# 146       4.5   155446  Varies with device     10,000,000+  Free      0
# 149       4.5   203130  Varies with device     10,000,000+  Free      0
# 152       3.9  1433233  Varies with device  1,000,000,000+  Free      0
# 157       4.2    87873  Varies with device     10,000,000+  Free      0
# 162       4.7    19080  Varies with device        500,000+  Free      0
# 172       4.3    64513  Varies with device      5,000,000+  Free      0
# 173       4.2     8342  Varies with device     10,000,000+  Free      0
# 179       4.4   233757  Varies with device     10,000,000+  Free      0
# 187       4.1    16129  Varies with device     10,000,000+  Free      0
# ...       ...      ...                 ...             ...   ...    ...
# 10595     4.5       65                470k          5,000+  Free      0
# 10600     3.5      143                226k         10,000+  Free      0
# 10642     3.9     3023  Varies with device        500,000+  Free      0
# 10645     3.9    11460  Varies with device        100,000+  Paid  $8.99
# 10647     3.9    54815  Varies with device    100,000,000+  Free      0
# 10667     3.8      143                240k          5,000+  Free      0
# 10675     4.2        6                 89k             50+  Paid  $0.99
# 10677     2.5        6                234k            100+  Free      0
# 10678     3.5      159                257k         10,000+  Free      0
# 10679     4.6    11235  Varies with device        100,000+  Paid  $2.99
# 10681     4.6     1075  Varies with device        100,000+  Free      0
# 10688     4.5     1916                364k        100,000+  Free      0
# 10690     5.0        5                861k            100+  Paid  $0.99
# 10707     4.5  1519671  Varies with device    100,000,000+  Free      0
# 10712     4.4    61392  Varies with device      1,000,000+  Free      0
# 10713     4.4     3471  Varies with device        100,000+  Free      0
# 10725     3.6        8  Varies with device          1,000+  Free      0
# 10732     4.3     3268                467k        100,000+  Free      0
# 10735     NaN       17                157k            100+  Paid  $0.99
# 10751     NaN       24                 44k          1,000+  Free      0
# 10755     4.3      334                676k         10,000+  Free      0
# 10759     NaN       17                 67k          1,000+  Free      0
# 10763     4.5      922                552k         50,000+  Free      0
# 10764     NaN        1                885k              1+  Free      0
# 10765     3.4      622  Varies with device        100,000+  Free      0
# 10798     NaN        0               1020k             50+  Paid  $1.04
# 10826     4.0    88486  Varies with device      5,000,000+  Free      0
# 10832     3.8     1195                582k        100,000+  Free      0
# 10833     4.8       44                619k          1,000+  Free      0
# 10839     4.5      114  Varies with device          1,000+  Free      0
#
#       Content Rating                   Genres        Last Updated  \
# 37          Everyone             Art & Design       July 14, 2018
# 42          Everyone             Art & Design       July 30, 2018
# 52          Everyone          Auto & Vehicles       July 30, 2018
# 58          Everyone          Auto & Vehicles     August 26, 2014
# 67          Everyone          Auto & Vehicles       July 30, 2018
# 68          Everyone          Auto & Vehicles        May 25, 2018
# 73          Everyone          Auto & Vehicles       July 29, 2018
# 85          Everyone          Auto & Vehicles      August 4, 2018
# 88          Everyone          Auto & Vehicles      August 3, 2018
# 89          Everyone          Auto & Vehicles        May 10, 2018
# 92          Everyone          Auto & Vehicles      August 2, 2018
# 102         Everyone                   Beauty    October 24, 2016
# 107         Everyone                   Beauty        June 5, 2018
# 109         Everyone                   Beauty  September 12, 2017
# 117         Everyone                   Beauty      August 3, 2017
# 118         Everyone                   Beauty        May 24, 2018
# 139             Teen        Books & Reference      August 1, 2018
# 142         Everyone        Books & Reference      August 2, 2018
# 143             Teen        Books & Reference       July 27, 2018
# 144         Everyone        Books & Reference       July 17, 2015
# 145         Everyone        Books & Reference        May 18, 2018
# 146             Teen        Books & Reference      April 25, 2018
# 149         Everyone        Books & Reference       June 28, 2018
# 152             Teen        Books & Reference      August 3, 2018
# 157             Teen        Books & Reference        May 28, 2018
# 162         Everyone        Books & Reference      April 25, 2018
# 172         Everyone        Books & Reference       July 31, 2018
# 173         Everyone        Books & Reference     August 28, 2017
# 179         Everyone        Books & Reference         May 1, 2018
# 187         Everyone                 Business       July 30, 2018
# ...              ...                      ...                 ...
# 10595       Everyone                Education    January 30, 2016
# 10600       Everyone         Health & Fitness       June 12, 2013
# 10642       Everyone                 Shopping       July 26, 2018
# 10645       Everyone                   Sports       June 27, 2018
# 10647       Everyone  Video Players & Editors         May 2, 2018
# 10667       Everyone          Personalization       July 31, 2013
# 10675       Everyone          Personalization      August 9, 2013
# 10677       Everyone          Personalization     August 10, 2013
# 10678       Everyone          Personalization     August 16, 2013
# 10679       Everyone                     Card       July 30, 2018
# 10681       Everyone             Productivity    January 22, 2018
# 10688       Everyone                    Tools   December 31, 2015
# 10690       Everyone          Personalization      April 25, 2018
# 10707       Everyone              Photography    February 1, 2018
# 10712       Everyone                 Shopping      August 8, 2018
# 10713       Everyone                  Weather       July 24, 2018
# 10725       Everyone        Maps & Navigation  September 27, 2017
# 10732       Everyone                    Tools   December 16, 2017
# 10735     Mature 17+            Entertainment   November 25, 2015
# 10751       Everyone                Education       June 17, 2012
# 10755       Everyone        Maps & Navigation     August 23, 2016
# 10759       Everyone                    Tools    January 29, 2016
# 10763       Everyone            Entertainment  September 20, 2014
# 10764       Everyone          Auto & Vehicles       March 9, 2018
# 10765     Mature 17+                   Social        May 23, 2018
# 10798       Everyone                   Puzzle    February 6, 2012
# 10826     Mature 17+                   Social      March 23, 2018
# 10832       Everyone                  Weather   February 16, 2014
# 10833       Everyone        Books & Reference      March 23, 2014
# 10839     Mature 17+        Books & Reference    January 19, 2015
#
#               Current Ver         Android Ver  Reviews_numeric  \
# 37     Varies with device        2.3.3 and up          36639.0
# 42     Varies with device  Varies with device         295221.0
# 52     Varies with device  Varies with device          17057.0
# 58                  1.0.1          2.2 and up           1403.0
# 67     Varies with device  Varies with device          40211.0
# 68     Varies with device  Varies with device            356.0
# 73                    2.9        2.3.3 and up            736.0
# 85     Varies with device  Varies with device          21777.0
# 88     Varies with device  Varies with device          13372.0
# 89                  4.6.5  Varies with device           7880.0
# 92     Varies with device        4.0.3 and up          65786.0
# 102    Varies with device  Varies with device          32090.0
# 107                   5.4          5.0 and up          42050.0
# 109    Varies with device  Varies with device          17934.0
# 117    Varies with device  Varies with device         113715.0
# 118    Varies with device          4.0 and up           3595.0
# 139    Varies with device  Varies with device        2914724.0
# 142    Varies with device  Varies with device         577550.0
# 143    Varies with device  Varies with device         814080.0
# 144    Varies with device          1.5 and up         246315.0
# 145    Varies with device  Varies with device         454060.0
# 146    Varies with device  Varies with device         155446.0
# 149    Varies with device  Varies with device         203130.0
# 152    Varies with device  Varies with device        1433233.0
# 157    Varies with device  Varies with device          87873.0
# 162    Varies with device  Varies with device          19080.0
# 172    Varies with device  Varies with device          64513.0
# 173           9.00.950462          7.0 and up           8342.0
# 179    Varies with device  Varies with device         233757.0
# 187    Varies with device  Varies with device          16129.0
# ...                   ...                 ...              ...
# 10595                 2.0          2.1 and up             65.0
# 10600                 1.1          2.2 and up            143.0
# 10642  Varies with device  Varies with device           3023.0
# 10645  Varies with device          4.1 and up          11460.0
# 10647  Varies with device  Varies with device          54815.0
# 10667                 1.0          2.2 and up            143.0
# 10675                 1.0          2.2 and up              6.0
# 10677                 1.0          2.2 and up              6.0
# 10678                 1.0          2.2 and up            159.0
# 10679  Varies with device  Varies with device          11235.0
# 10681  Varies with device          4.4 and up           1075.0
# 10688               1.8.8          2.1 and up           1916.0
# 10690                 0.2          7.0 and up              5.0
# 10707  Varies with device  Varies with device        1519671.0
# 10712  Varies with device  Varies with device          61392.0
# 10713  Varies with device  Varies with device           3471.0
# 10725  Varies with device          4.4 and up              8.0
# 10732                 6.6          2.0 and up           3268.0
# 10735                 1.2          2.1 and up             17.0
# 10751                 1.0          1.6 and up             24.0
# 10755                 1.3        2.3.3 and up            334.0
# 10759                 1.1          4.0 and up             17.0
# 10763                 1.1          1.6 and up            922.0
# 10764              10.0.0          4.0 and up              1.0
# 10765  Varies with device  Varies with device            622.0
# 10798                 1.1          3.0 and up              0.0
# 10826  Varies with device  Varies with device          88486.0
# 10832                 6.0          2.1 and up           1195.0
# 10833                 0.8          2.2 and up             44.0
# 10839  Varies with device  Varies with device            114.0
#
#        Reviews_isnull  Size_numeric  Size_isnull
# 37              False           NaN         True
# 42              False           NaN         True
# 52              False           NaN         True
# 58              False           NaN         True
# 67              False           NaN         True
# 68              False           NaN         True
# 73              False           NaN         True
# 85              False           NaN         True
# 88              False           NaN         True
# 89              False           NaN         True
# 92              False           NaN         True
# 102             False           NaN         True
# 107             False           NaN         True
# 109             False           NaN         True
# 117             False           NaN         True
# 118             False           NaN         True
# 139             False           NaN         True
# 142             False           NaN         True
# 143             False           NaN         True
# 144             False           NaN         True
# 145             False           NaN         True
# 146             False           NaN         True
# 149             False           NaN         True
# 152             False           NaN         True
# 157             False           NaN         True
# 162             False           NaN         True
# 172             False           NaN         True
# 173             False           NaN         True
# 179             False           NaN         True
# 187             False           NaN         True
# ...               ...           ...          ...
# 10595           False           NaN         True
# 10600           False           NaN         True
# 10642           False           NaN         True
# 10645           False           NaN         True
# 10647           False           NaN         True
# 10667           False           NaN         True
# 10675           False           NaN         True
# 10677           False           NaN         True
# 10678           False           NaN         True
# 10679           False           NaN         True
# 10681           False           NaN         True
# 10688           False           NaN         True
# 10690           False           NaN         True
# 10707           False           NaN         True
# 10712           False           NaN         True
# 10713           False           NaN         True
# 10725           False           NaN         True
# 10732           False           NaN         True
# 10735           False           NaN         True
# 10751           False           NaN         True
# 10755           False           NaN         True
# 10759           False           NaN         True
# 10763           False           NaN         True
# 10764           False           NaN         True
# 10765           False           NaN         True
# 10798           False           NaN         True
# 10826           False           NaN         True
# 10832           False           NaN         True
# 10833           False           NaN         True
# 10839           False           NaN         True
#
# [2012 rows x 17 columns]

# %% [markdown]
# #### While this column may be useful for other types of analysis, we opt to drop it from our dataset.
#
# There are two reasons. First, the majority of the data are ordinal but a sizeable proportion are missing because we cannot convert them to numerical values. Ordinal data are both numerical and categorical, and they usually can be ranked (e.g. 82k is smaller than 91M). In contrast, non-ordinal categorical data such as blood type and eye color cannot be ranked. The second reason is as a categorical column, it has too many unique values to produce meaningful insights. Therefore, in our case the simplest strategy would be to drop the column.
#
# Drop the column in the cell below (use `inplace=True`)

# %%
# Your code here:
google_play.drop(["Size", "Size_numeric", "Size_isnull"], axis=1, inplace=True)

# %% [markdown]
# #### Now let's look at how many missing values are in each column.
#
# This will give us an idea of whether we should come up with a missing data strategy or give up on the column all together. In the next column, find the number of missing values in each column:
#
# *Hint: use the `isna()` and `sum()` functions.*

# %%
# Your code here:
google_play.isna().sum()/len(google_play) * 100
# Out:
# App                 0.000000
# Category            0.000000
# Rating             13.596532
# Reviews             0.000000
# Installs            0.000000
# Type                0.009224
# Price               0.000000
# Content Rating      0.009224
# Genres              0.000000
# Last Updated        0.000000
# Current Ver         0.073794
# Android Ver         0.027673
# Reviews_numeric     0.000000
# Reviews_isnull      0.000000
# dtype: float64

# %% [markdown]
# You should find the column with the most missing values is now `Rating`.
#
# #### What is the proportion of the missing values in `Rating` to the total number of records?
#
# Enter your answer in the cell below.

# %%
# Your code here:
google_play.isna().sum()["Rating"]/len(google_play)*100
# Out:
# 13.596531685268886

# %% [markdown]
# A sizeable proportion of the `Rating` column is missing. A few other columns also contain several missing values.
#
# #### We opt to preserve these columns and remove the rows containing missing data.
#
# In particular, we don't want to drop the `Rating` column because:
#
# * It is one of the most important columns in our dataset.
#
# * Since the dataset is not a time series, the loss of these rows will not have a negative impact on our ability to analyze the data. It will, however, cause us to lose some meaningful observations. But the loss is limited compared to the gain we receive by preserving these columns.
#
# In the cell below, remove all rows containing at least one missing value. Use the `dropna()` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)). Assign the new dataframe to the variable `google_missing_removed`.

# %%
# Your code here:
google_missing_removed = google_play.dropna()

# %% [markdown]
# From now on, we use the `google_missing_removed` variable instead of `google_play`.
#
# #### Next, we look at the `Last Updated` column.
#
# The `Last Updated` column seems to contain a date, though it is classified as an object type. Let's convert this column using the `pd.to_datetime` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)).

# %%
# Your code here:
google_missing_removed["Last Updated"] = pd.to_datetime(google_missing_removed["Last Updated"],  errors='coerce')
# Out:
# C:\Users\fabia hnt\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### The last column we will transform is `Price`.
#
# We start by looking at the unique values of this column.

# %%
# Your code here:
google_missing_removed.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %% [markdown]
# Since all prices are ordinal data without exceptions, we can tranform this column by removing the dollar sign and converting to numeric. We can create a new column called `Price Numerical` and drop the original column.
#
# We will achieve our goal in three steps. Follow the instructions of each step below.
#
# #### First we remove the dollar sign. Do this in the next cell by applying the `str.replace` function to the column to replace `$` with an empty string (`''`).

# %%
# Your code here:
# Your code here

def convert_string_to_numeric(s):
    return float(s.replace ("$", ""))

# %%
google_missing_removed["Price"] = google_missing_removed["Price"].apply(convert_string_to_numeric)
# Out:
# C:\Users\fabia hnt\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Second step, coerce the `Price Numerical` column to numeric.

# %%
# Your code here:
google_missing_removed["Price_numeric"] = google_missing_removed["Price"].apply(pd.to_numeric, errors='coerce')
google_missing_removed["Price_isnull"] = google_missing_removed["Price_numeric"].isnull()
google_missing_removed[google_missing_removed["Price_isnull"]==True]
# Out:
# C:\Users\fabia hnt\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\fabia hnt\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Reviews_numeric, Reviews_isnull, Price_numeric, Price_isnull]
# Index: []

# %% [markdown]
# **Finally, drop the original `Price` column.**

# %%
# Your code here:
google_missing_removed.drop(["Price", "Price_isnull"], axis=1, inplace=True)
# Out:
# C:\Users\fabia hnt\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# Now check the variable types of `google_missing_removed`. Make sure:
#
# * `Size` and `Price` columns have been removed.
# * `Rating`, `Reviews`, and `Price Numerical` have the type of `float64`.
# * `Last Updated` has the type of `datetime64`.

# %%
# Your code here
google_missing_removed.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                    object
# Installs                   object
# Type                       object
# Content Rating             object
# Genres                     object
# Last Updated       datetime64[ns]
# Current Ver                object
# Android Ver                object
# Reviews_numeric           float64
# Reviews_isnull               bool
# Price_numeric             float64
# dtype: object

# %%
# realised the reviews are sitll in :
google_missing_removed.drop(["Reviews", "Reviews_isnull"], axis=1, inplace=True)

# %%
google_missing_removed.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#       Installs  Type Content Rating                     Genres Last Updated  \
# 0      10,000+  Free       Everyone               Art & Design   2018-01-07
# 1     500,000+  Free       Everyone  Art & Design;Pretend Play   2018-01-15
# 2   5,000,000+  Free       Everyone               Art & Design   2018-08-01
# 3  50,000,000+  Free           Teen               Art & Design   2018-06-08
# 4     100,000+  Free       Everyone    Art & Design;Creativity   2018-06-20
#
#           Current Ver   Android Ver  Reviews_numeric  Price_numeric
# 0               1.0.0  4.0.3 and up            159.0            0.0
# 1               2.0.0  4.0.3 and up            967.0            0.0
# 2               1.2.4  4.0.3 and up          87510.0            0.0
# 3  Varies with device    4.2 and up         215644.0            0.0
# 4                 1.1    4.4 and up            967.0            0.0

# %% [markdown]
# # Challenge 2 - Loading and Extracting Features from the Second Dataset

# %% [markdown]
# Load the second dataset to the variable `google_reviews`. The data is in the file `googleplaystore_user_reviews.csv`.

# %%
# Your code here:
google_reviews = pd.read_csv("../../data/googleplaystore_user_reviews.csv")

# %% [markdown]
# #### This dataset contains the top 100 reviews for each app.
#
# Let's examine this dataset using the `head` function

# %%
# Your code here
google_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# #### The main piece of information we would like to extract from this dataset is the proportion of positive reviews of each app.
#
# Columns like `Sentiment_Polarity` and `Sentiment_Subjectivity` are not to our interests because we have no clue how to use them. We do not care about `Translated_Review` because natural language processing is too complex for us at present (in fact the `Sentiment`, `Sentiment_Polarity`, and `Sentiment_Subjectivity` columns are derived from `Translated_Review` the data scientists).
#
# What we care about in this challenge is `Sentiment`. To be more precise, we care about **what is the proportion of *Positive* sentiment of each app**. This will require us to aggregate the `Sentiment` data by `App` in order to calculate the proportions.
#
# Now that you are clear about what we are trying to achieve, follow the steps below that will walk you through towards our goal.

# %% [markdown]
# #### Our first step will be to remove all rows with missing sentiment.
#
# In the next cell, drop all rows with missing data using the `dropna()` function and assign this new dataframe to `review_missing_removed`.

# %%
# Your code here:
review_missing_removed = google_reviews.dropna()

# %%
review_missing_removed = review_missing_removed[["App", "Sentiment"]]
review_missing_removed.head()
# Out:
#                      App Sentiment
# 0  10 Best Foods for You  Positive
# 1  10 Best Foods for You  Positive
# 3  10 Best Foods for You  Positive
# 4  10 Best Foods for You  Positive
# 5  10 Best Foods for You  Positive

# %% [markdown]
# #### Now, use the `value_counts()` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html)) to get a sense on how many apps are in this dataset and their review counts.

# %%
# Your code here:
review_missing_removed.App.value_counts()
# Out:
# Bowmasters                                            312
# Helix Jump                                            273
# Angry Birds Classic                                   273
# Calorie Counter - MyFitnessPal                        254
# Duolingo: Learn Languages Free                        240
# Candy Crush Saga                                      240
# Garena Free Fire                                      222
# 8 Ball Pool                                           219
# Calorie Counter - Macros                              200
# 10 Best Foods for You                                 194
# CBS Sports App - Scores, News, Stats & Watch Live     192
# Google Photos                                         191
# Alto's Adventure                                      175
# 8fit Workouts & Meal Planner                          171
# DRAGON BALL LEGENDS                                   167
# Candy Crush Soda Saga                                 166
# Clash Royale                                          165
# Adobe Acrobat Reader                                  162
# Episode - Choose Your Story                           160
# Block Puzzle                                          154
# Flow Free                                             154
# Bubble Shooter                                        145
# Calorie Counter - MyNetDiary                          139
# Agar.io                                               136
# Cooking Fever                                         135
# Calorie Counter & Diet Tracker                        135
# Galaxy Attack: Alien Shooter                          134
# Colorfy: Coloring Book for Adults - Free              133
# Gardenscapes                                          133
# Facebook                                              132
#                                                      ...
# Disney Heroes: Battle Mode                              2
# 3D Live Neon Weed Launcher                              2
# Calendar Widget Month + Agenda                          2
# Google Primer                                           2
# Extreme Car Driving Simulator                           2
# Calendar+ Schedule Planner App                          1
# Free Live Talk-Video Call                               1
# Caf - Mon Compte                                        1
# Fruit Block - Puzzle Legend                             1
# HD Camera                                               1
# CallApp: Caller ID, Blocker & Phone Call Recorder       1
# GPS Map Free                                            1
# Drawing for Kids Learning Games for Toddlers age 3      1
# Draw A Stickman                                         1
# Best Fiends - Free Puzzle Game                          1
# Google Slides                                           1
# Google Trips - Travel Planner                           1
# All-in-One Mahjong 3 FREE                               1
# CBS News                                                1
# Apartment Decorating Ideas                              1
# Draw In                                                 1
# Daily Workouts - Exercise Fitness Routine Trainer       1
# Best Ovulation Tracker Fertility Calendar App Glow      1
# Discover Mobile                                         1
# Caller ID +                                             1
# Calculator - unit converter                             1
# HomeWork                                                1
# DashClock Widget                                        1
# Bed Time Fan - White Noise Sleep Sounds                 1
# Draw a Stickman: EPIC 2                                 1
# Name: App, Length: 865, dtype: int64

# %% [markdown]
# #### Now the tough part comes. Let's plan how we will achieve our goal:
#
# 1. We will count the number of reviews that contain *Positive* in the `Sentiment` column.
#
# 1. We will create a new dataframe to contain the `App` name, the number of positive reviews, and the total number of reviews of each app.
#
# 1. We will then loop the new dataframe to calculate the postivie review portion of each app.

# %% [markdown]
# #### Step 1: Count the number of positive reviews.
#
# In the following cell, write a function that takes a column and returns the number of times *Positive* appears in the column.
#
# *Hint: One option is to use the `np.where()` function ([documentation](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.where.html)).*

# %%
# Your code below

def positive_function(x):
    count = np.where(x == "Positive", 1,0)
    return count.sum()

# %% [markdown]
# #### Step 2: Create a new dataframe to contain the `App` name, the number of positive reviews, and the total number of reviews of each app
#
# We will group `review_missing_removed` by the `App` column, then aggregate the grouped dataframe on the number of positive reviews and the total review counts of each app. The result will be assigned to a new variable `google_agg`. Here is the ([documentation on how to achieve it](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.DataFrameGroupBy.agg.html)). Take a moment or two to read the documentation and google examples because it is pretty complex.
#
# When you obtain `google_agg`, check its values to make sure it has an `App` column as its index as well as a `Positive` column and a `Total` column. Your output should look like:
#
# ![Positive Reviews Agg](../images/positive-review-agg.png)
#
# *Hint: Use `positive_function` you created earlier as part of the param passed to the `agg()` function in order to aggregate the number of positive reviews.*

# %%
google_agg = review_missing_removed.groupby("App").agg({"Sentiment": [positive_function, "count"]})
google_agg.head()
# Out:
#                                          Sentiment
#                                  positive_function count
# App
# 10 Best Foods for You                          162   194
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                31    40
# 11st                                            23    39
# 1800 Contacts - Lens Store                      64    80
# 1LINE – One Line with One Touch                 27    38

# %% [markdown]
# #### Bonus:
#
# As of Pandas v0.23.4, you may opt to supply an array or an object to `agg()`. If you use the array param, you'll need to rename the columns so that their names are `Positive` and `Total`. Using the object param will allow you to create the aggregated columns with the desirable names without renaming them. However, you will probably encounter a warning indicating supplying an object to `agg()` will become outdated. It's up to you which way you will use. Try both ways out. Any way is fine as long as it works.

# %%
# Your code here:
review_missing_removed.head()
# Out:
#                      App Sentiment
# 0  10 Best Foods for You  Positive
# 1  10 Best Foods for You  Positive
# 3  10 Best Foods for You  Positive
# 4  10 Best Foods for You  Positive
# 5  10 Best Foods for You  Positive

# %% [markdown]
# Print the first 5 rows of `google_agg` to check it.

# %%
# Your code here

# %% [markdown]
# #### Add a derived column to `google_agg` that is the ratio of the `Positive` and the `Total` columns. Call this column `Positive Ratio`.
#
# Make sure to account for the case where the denominator is zero using the `np.where()` function.

# %%
# Your code here:
google_agg["Positive Ratio"] = google_agg[("Sentiment", "positive_function")]/google_agg[("Sentiment", "count")]
google_agg.head()
# Out:
#                                          Sentiment       Positive Ratio
#                                  positive_function count
# App
# 10 Best Foods for You                          162   194       0.835052
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                31    40       0.775000
# 11st                                            23    39       0.589744
# 1800 Contacts - Lens Store                      64    80       0.800000
# 1LINE – One Line with One Touch                 27    38       0.710526

# %% [markdown]
# #### Now drop the `Positive` and `Total` columns. Do this with `inplace=True`.

# %%
# Your code here:
google_agg.drop("Sentiment", axis=1, inplace=True)

# %%
google_agg.head()
# Out:
#                                  Positive Ratio
#
# App
# 10 Best Foods for You                  0.835052
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室       0.775000
# 11st                                   0.589744
# 1800 Contacts - Lens Store             0.800000
# 1LINE – One Line with One Touch        0.710526

# %% [markdown]
# Print the first 5 rows of `google_agg`. Your output should look like:
#
# ![Positive Reviews Agg](../images/positive-review-ratio.png)

# %%
# Your code here:

# %% [markdown]
# # Challenge 3 - Join the Dataframes
#
# In this part of the lab, we will join the two dataframes and obtain a dataframe that contains features we can use in our ML algorithm.
#
# In the next cell, join the `google_missing_removed` dataframe with the `google_agg` dataframe on the `App` column. Assign this dataframe to the variable `google`.

# %%
# Your code here:
google = google_missing_removed.merge(google_agg, "inner", on="App")
google.head()
# Out:
#                                          App        Category  Rating  \
# 0                        Coloring book moana  ART_AND_DESIGN     3.9
# 1                        Coloring book moana          FAMILY     3.9
# 2                       Garden Coloring Book  ART_AND_DESIGN     4.4
# 3              FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 4  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1
#
#      Installs  Type Content Rating                     Genres Last Updated  \
# 0    500,000+  Free       Everyone  Art & Design;Pretend Play   2018-01-15
# 1    500,000+  Free       Everyone  Art & Design;Pretend Play   2018-01-15
# 2  1,000,000+  Free       Everyone               Art & Design   2017-09-20
# 3  5,000,000+  Free       Everyone               Art & Design   2018-08-03
# 4    100,000+  Free       Everyone               Art & Design   2018-03-20
#
#   Current Ver   Android Ver  Reviews_numeric  Price_numeric  \
# 0       2.0.0  4.0.3 and up            967.0            0.0
# 1       2.0.0  4.0.3 and up            974.0            0.0
# 2       2.9.2    3.0 and up          13791.0            0.0
# 3       2.2.5  4.0.3 and up         194216.0            0.0
# 4         1.1  4.0.3 and up            654.0            0.0
#
#    (Positive Ratio, )
# 0            0.590909
# 1            0.590909
# 2            0.711111
# 3            1.000000
# 4            0.605263

# %% [markdown]
# #### Let's look at the final result using the `head()` function. Your final product should look like:
#
# ![Final Product](../images/google-final-head.png)

# %%
# Your code here:
